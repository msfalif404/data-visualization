# %% [markdown]
# # Create Multiple Lineplot

# %% [markdown]
# ## Import Library

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Creating Synthetic Dataframe

# %%
tanggal = pd.date_range(start = '2021-01-01', end = '2024-01-01', freq = 'D')
harga_saham = np.random.randn(len(tanggal)).cumsum() + 100

# %% [markdown]
# ## Creating Dataframe

# %%
df = pd.DataFrame({
    'tanggal': tanggal,
    'harga_saham': harga_saham
})

df.head()
# Out:
#      tanggal  harga_saham
# 0 2021-01-01    98.895129
# 1 2021-01-02    98.793865
# 2 2021-01-03    98.612824
# 3 2021-01-04    97.366187
# 4 2021-01-05    98.580750

# %% [markdown]
# ## Adding More Data

# %%
harga_obligasi = np.random.randn(len(tanggal)).cumsum() + 70

df['harga_obligasi'] = harga_obligasi
df.head()
# Out:
#      tanggal  harga_saham  harga_obligasi
# 0 2021-01-01    98.895129       70.373554
# 1 2021-01-02    98.793865       71.188260
# 2 2021-01-03    98.612824       71.923349
# 3 2021-01-04    97.366187       70.411517
# 4 2021-01-05    98.580750       72.263359

# %% [markdown]
# ## Different Lineplot With Rolling Mean

# %%
df['30d_average'] = df['harga_saham'].rolling(window = 30).mean()

plt.figure(figsize=(14,7))
plt.plot(df['tanggal'], df['harga_saham'], color='blue', label='Harga Saham')
plt.plot(df['tanggal'], df['30d_average'], color='orange', linestyle='--', label = 'Rata-rata Bergerak 30 Hari')
plt.title('Harga Saham dengan Rata-rata Bergerak 30 Hari')
plt.xlabel('Tanggal')
plt.ylabel('Harga')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Area Under Curve

# %%
df['30d_average'] = df['harga_saham'].rolling(window = 30).mean()

plt.figure(figsize=(14,7))
plt.plot(df['tanggal'], df['harga_saham'], color='blue', label='Harga Saham')
plt.plot(df['tanggal'], df['30d_average'], color='orange', linestyle='--', label = 'Rata-rata Bergerak 30 Hari')
plt.fill_between(df['tanggal'], df['30d_average'], color='orange', alpha = 0.25)
plt.title('Harga Saham dengan Rata-rata Bergerak 30 Hari')
plt.xlabel('Tanggal')
plt.ylabel('Harga')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## More Clear Example

# %%
plt.figure(figsize=(14,7))
plt.plot(df['tanggal'], df['30d_average'], linestyle='--', color='orange', label = 'Rata-rata Bergerak 30 Hari')
plt.fill_between(df['tanggal'], df['30d_average'], color='orange', alpha=0.25)
plt.title('Harga Saham dengan Rata-rata Bergerak 30 Hari')
plt.xlabel('Tanggal')
plt.ylabel('Harga')
plt.grid(True)
plt.tight_layout()
plt.legend()
plt.show()

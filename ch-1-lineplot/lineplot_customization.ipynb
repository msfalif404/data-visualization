# %% [markdown]
# # Basic Lineplot

# %% [markdown]
# ## Importing Library

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Creating Synthetic Data

# %%
tanggal = pd.date_range(start = '2021-01-01', end = '2024-01-01', freq = 'D')
harga_saham = np.random.randn(len(tanggal)).cumsum() + 100

# %% [markdown]
# ## Creating Dataframe

# %%
df = pd.DataFrame({
    'tanggal': tanggal,
    'harga_saham': harga_saham
})

df.head()
# Out:
#      tanggal  harga_saham
# 0 2021-01-01   100.655918
# 1 2021-01-02   101.746276
# 2 2021-01-03   102.393620
# 3 2021-01-04   103.670645
# 4 2021-01-05   104.101284

# %% [markdown]
# ## Creating Line Plot

# %%
plt.figure(figsize = (12,6))
plt.plot(df['tanggal'], df['harga_saham'], color = 'blue', label = 'harga_saham')
plt.title('Perubahan Harga Saham Selama Tahun 2021-2024')
plt.xlabel('Tanggal')
plt.ylabel('Harga Saham')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Lineplot Customization

# %%
plt.figure(figsize=(12,6))
plt.plot(df['tanggal'], df['harga_saham'], color = 'green', marker = '*', linestyle='-', label = 'Harga Saham')
plt.title('Perubahan Harga Saham Selama Tahun 2022 dengan Kustomisasi')
plt.xlabel("Tanggal")
plt.ylabel("Harga Saham")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

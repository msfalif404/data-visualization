# %% [markdown]
# # Create Multiple Lineplot

# %% [markdown]
# ## Import Library

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Creating Synthetic Dataframe

# %%
tanggal = pd.date_range(start = '2021-01-01', end = '2024-01-01', freq = 'D')
harga_saham = np.random.randn(len(tanggal)).cumsum() + 100

# %% [markdown]
# ## Creating Dataframe

# %%
df = pd.DataFrame({
    'tanggal': tanggal,
    'harga_saham': harga_saham
})

df.head()
# Out:
#      tanggal  harga_saham
# 0 2021-01-01   101.001113
# 1 2021-01-02   100.538049
# 2 2021-01-03   102.808922
# 3 2021-01-04   104.098872
# 4 2021-01-05   104.118737

# %% [markdown]
# ## Adding More Data

# %%
harga_obligasi = np.random.randn(len(tanggal)).cumsum() + 70

df['harga_obligasi'] = harga_obligasi
df.head()
# Out:
#      tanggal  harga_saham  harga_obligasi
# 0 2021-01-01   101.001113       68.014589
# 1 2021-01-02   100.538049       68.084220
# 2 2021-01-03   102.808922       67.531716
# 3 2021-01-04   104.098872       67.285414
# 4 2021-01-05   104.118737       66.707982

# %% [markdown]
# ## Creating Multiple Lineplot

# %%
plt.figure(figsize=(14,7))
plt.plot(df['tanggal'], df['harga_saham'], color = 'blue', label = 'Harga Saham')
plt.plot(df['tanggal'], df['harga_obligasi'], color = 'red', linestyle='--', label = 'Harga Obligasi')
plt.title('Perbandingan Harga Saham dan Obligasi Selama Tahun 2022')
plt.xlabel('Tanggal')
plt.ylabel('Harga')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
